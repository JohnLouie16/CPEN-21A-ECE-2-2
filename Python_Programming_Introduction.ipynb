# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnLouie16/CpEN-2-2/blob/main/Python_Programming_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Review of Python

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
x = 'Python programming is '
y = "enjoying"
print(x+y)
# Out:
# Python programming is enjoying

# %%
a , b ,c = 0, -1, 8
c%=3
print(c)
# Out:
# 2

# %%
x=5
x>5 or x<11
# Out:
# True
